# %%
from vnstock import Company, Listing, Quote, Finance

# %%
company = Company(symbol="FBA",source="VCI")
company.overview()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File d:\anaconda\envs\tf_env\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File d:\anaconda\envs\tf_env\Lib\site-packages\vnstock\base.py:27, in dynamic_method.<locals>.wrapper(self, *args, **kwargs)
#      26 filtered = {k: v for k, v in kwargs.items() if k in sig.parameters}
# ---> 27 return provider_method(*args, **filtered)
#
# File d:\anaconda\envs\tf_env\Lib\site-packages\vnai\beam\quota.py:291, in _create_wrapper.<locals>.wrapper(*args, **kwargs)
#     290 try:
# --> 291     result = func(*args, **kwargs)
#     292     success = True
#
# File d:\anaconda\envs\tf_env\Lib\site-packages\vnstock\explorer\vci\company.py:131, in Company.overview(self)
# ...

# %%
company.shareholders()
# Out:
#           id                            share_holder    quantity  \
# 0   96798315             Ngân Hàng Nhà Nước Việt Nam  6250338579
# 1   96798260                     Mizuho Bank Limited  1253366534
# 2   96810760    Quỹ Đầu tư Chính phủ Singapore (GIC)    84503639
# 3   96816575  Vietnam Enterprise Investments Limited    11142740
# 4   96815730           T. Rowe Price Associates, Inc    12522661
# 5   96816615                     Vietnam Holding Ltd     1428898
# 6   96811141                Quỹ ETF SSIAM VNFIN LEAD     1208480
# 7   96810850            Quỹ Đầu tư Cổ phiếu Manulife      252294
# 8   96810910             Quỹ Đầu tư Cổ phiếu Techcom      103030
# 9   96790388                        Đậu Thị Thúy Vân       75974
# 10  96811183                     Quỹ ETF SSIAM VNX50       77090
# 11  96810752            Quỹ Đầu tư Cân bằng Manulife       71950
# 12  96811051             Quỹ Đầu tư Tăng trưởng DFVN       65000
# ...

# %%
listing = Listing(source= "VCI")

# %%
df_1 = listing.all_symbols()

# %%
df_1.shape
# Out:
# (1733, 2)

# %%
df_2 = listing.symbols_by_exchange()

# %%
df_2.shape
# Out:
# (3210, 7)

# %%
df_2
# Out:
#          symbol exchange   type                          organ_short_name  \
# 0           YTC    UPCOM  STOCK                           XNK Y tế TP.HCM
# 1           YEG      HSX  STOCK                            Tập đoàn Yeah1
# 2           YBM      HSX  STOCK                     Khoáng sản CN Yên Bái
# 3           YBC    UPCOM  STOCK             Xi măng và Khoáng sản Yên Bái
# 4           XPH    UPCOM  STOCK                           Xà phòng Hà Nội
# ...         ...      ...    ...                                       ...
# 3224  41BAG6000      HNX     FU  10-year Government Bond   Futures 062026
# 3225  41BAG3000      HNX     FU  10-year Government Bond   Futures 032026
# 3226  41B5G9000      HNX     FU  5-year Government Bond    Futures 092026
# 3227  41B5G6000      HNX     FU  5-year Government Bond    Futures 062026
# 3228  41B5G3000      HNX     FU  5-year Government Bond    Futures 032026
#
#                                              organ_name product_grp_id  \
# ...

# %%
df_2[df_2['symbol']=='FBA']
# Out:
#      symbol exchange   type      organ_short_name  \
# 1433    FBA    UPCOM  STOCK  Tập đoàn Quốc tế FBA
#
#                                 organ_name product_grp_id icb_code2
# 1433  Công ty Cổ phần Tập đoàn Quốc tế FBA            UPX      3700

# %%
df_2['organ_short_name'].isnull().count()
# Out:
# 3229

# %%
df_2['type'].unique()
# Out:
# array(['STOCK', 'BOND', 'FU', 'DEBENTURE', 'ETF', 'UNIT_TRUST', 'CW'],
#       dtype=object)

# %%
df_1[df_1["symbol"] == "VVN30F2501"]
# Out:
# Empty DataFrame
# Columns: [symbol, organ_name]
# Index: []

# %%
quote = Quote(symbol= "VCI",source="VCI")

# %%
listing.symbols_by_industries()
# Out:
#      symbol                                         organ_name  \
# 0       BQP     Công ty Cổ phần Nhựa chất lượng cao Bình Thuận
# 1       VLS            Công ty Cổ phần Sản xuất Thép Việt Long
# 2       F88                         Công ty Cổ phần Đầu tư F88
# 3       DVT  Công ty Cổ phần Đào tạo và Dịch vụ Giao thông ...
# 4       APF      Công ty Cổ phần Nông sản Thực phẩm Quảng Ngãi
# ...     ...                                                ...
# 1564    PTT         Công ty Cổ phần Vận tải Dầu khí Đông Dương
# 1565    SDG                     Công ty Cổ phần Sadico Cần Thơ
# 1566    TIS              Công ty Cổ phần Gang thép Thái Nguyên
# 1567    TVM  Công ty Cổ phần Tư vấn đầu tư Mỏ và công nghiệ...
# 1568    VIN  Công ty Cổ phần Giao nhận Kho vận Ngoại thương...
#
#                        icb_name3                   icb_name2  \
# 0                       Hóa chất                    Hóa chất
# 1                       Kim loại           Tài nguyên Cơ bản
# ...

# %%
quote.intraday(page_size=500)
# Out:
#                          time  price  volume match_type         id
# 0   2026-01-19 11:00:02+07:00  35.15     100        Buy  422781970
# 1   2026-01-19 11:00:12+07:00  35.15     100        Buy  422782426
# 2   2026-01-19 11:00:12+07:00  35.15     100        Buy  422782420
# 3   2026-01-19 11:00:12+07:00  35.15     100        Buy  422782421
# 4   2026-01-19 11:00:14+07:00  35.15     100        Buy  422782484
# ..                        ...    ...     ...        ...        ...
# 495 2026-01-19 11:29:58+07:00  35.05    1000        Buy  422852104
# 496 2026-01-19 11:29:58+07:00  35.05     100        Buy  422852105
# 497 2026-01-19 11:29:58+07:00  35.05     900        Buy  422852106
# 498 2026-01-19 11:29:58+07:00  35.00     100       Sell  422852107
# 499 2026-01-19 11:29:58+07:00  35.00     400       Sell  422852108
#
# [500 rows x 5 columns]

# %%
quote.history(start='2020-01-01',end='2024-01-01', interval='1m')
# Out:
#                      time   open   high    low  close  volume
# 0     2023-09-11 09:15:00  35.44  35.44  35.40  35.44   64900
# 1     2023-09-11 09:16:00  35.44  35.44  35.21  35.40   19300
# 2     2023-09-11 09:17:00  35.40  35.40  35.29  35.29    8800
# 3     2023-09-11 09:18:00  35.29  35.29  35.21  35.21   14400
# 4     2023-09-11 09:19:00  35.21  35.21  35.10  35.14   48400
# ...                   ...    ...    ...    ...    ...     ...
# 17820 2023-12-29 14:26:00  31.74  31.78  31.74  31.74   54600
# 17821 2023-12-29 14:27:00  31.74  31.74  31.74  31.74   14100
# 17822 2023-12-29 14:28:00  31.74  31.78  31.74  31.74    3500
# 17823 2023-12-29 14:29:00  31.74  31.74  31.71  31.74  188700
# 17824 2023-12-29 14:45:00  31.89  31.89  31.89  31.89  317900
#
# [17825 rows x 6 columns]

# %%
listing.industries_icb()
# Out:
#                                    icb_name  \
# 0                          Sản xuất Dầu khí
# 1    Thiết bị, Dịch vụ và Phân phối Dầu khí
# 2                                  Hóa chất
# 3                        Lâm nghiệp và Giấy
# 4                                  Kim loại
# ..                                      ...
# 150                              Viễn thông
# 151                      Tiện ích Cộng đồng
# 152                               Tài chính
# 153                               Ngân hàng
# 154                     Công nghệ Thông tin
#
#                                 en_icb_name icb_code  level
# 0                       Oil & Gas Producers     0530      3
# 1    Oil Equipment, Services & Distribution     0570      3
# 2                                 Chemicals     1350      3
# 3                          Forestry & Paper     1730      3
# 4                Industrial Metals & Mining     1750      3
# ..                                      ...      ...    ...
# ...

# %%
quote.price_depth(show_log = True)
# Out:
# 2026-01-18 19:27:17 - vnstock.core.utils.client - INFO - POST request to https://trading.vietcap.com.vn/api/market-watch/AccumulatedPriceStepVol/getSymbolData (mode: direct)
# 2026-01-18 19:27:17 - vnstock.core.utils.client - INFO - Payload: {'symbol': 'VCI'}
# 2026-01-18 19:27:17 - vnstock.core.utils.client - INFO - Sending direct request (no proxy)
#       price acc_volume acc_buy_volume acc_sell_volume acc_undefined_volume
# 0   35550.0    18500.0        18500.0             0.0                  0.0
# 1   35500.0   222200.0       194000.0         28200.0                  0.0
# 2   35450.0    61700.0        38200.0         23500.0                  0.0
# 3   35400.0   212800.0       161300.0         51500.0                  0.0
# 4   35350.0   154300.0        82800.0         71500.0                  0.0
# 5   35300.0   190100.0       120600.0         69500.0                  0.0
# 6   35250.0   281900.0       165200.0        116700.0                  0.0
# ...

# %%
finance = Finance(symbol='VCI',source='VCI')

# %%
df_3 =finance.income_statement(period='year',lang='vi')
df_3
# Out:
#      CP   Năm  Doanh thu (đồng)  Tăng trưởng doanh thu (%)  \
# 0   VCI  2024     3695525335470                   0.494675
# 1   VCI  2023     2472460543397                  -0.216644
# 2   VCI  2022     3156242736345                  -0.148588
# 3   VCI  2021     3707068724492                   1.143320
# 4   VCI  2020     1729591590563                   0.122423
# 5   VCI  2019     1540944352650                  -0.154015
# 6   VCI  2018     1821479495575                   0.185287
# 7   VCI  2017     1536741663856                   0.719618
# 8   VCI  2016      893653059787                   0.275369
# 9   VCI  2015      700701338901                   0.136233
# 10  VCI  2014      616688248624                   0.543810
# 11  VCI  2013      399458747857                  -0.138641
# 12  VCI  2011      463753810568                   0.000000
#
#     Lợi nhuận sau thuế của Cổ đông công ty mẹ (đồng)  \
# 0                                       910692113293
# ...

# %%
df_4 = finance.income_statement(period='year',lang='en')
df_4
# Out:
#    ticker  yearReport  Revenue (Bn. VND)  Revenue YoY (%)  \
# 0     VCI        2024      3695525335470         0.494675
# 1     VCI        2023      2472460543397        -0.216644
# 2     VCI        2022      3156242736345        -0.148588
# 3     VCI        2021      3707068724492         1.143320
# 4     VCI        2020      1729591590563         0.122423
# 5     VCI        2019      1540944352650        -0.154015
# 6     VCI        2018      1821479495575         0.185287
# 7     VCI        2017      1536741663856         0.719618
# 8     VCI        2016       893653059787         0.275369
# 9     VCI        2015       700701338901         0.136233
# 10    VCI        2014       616688248624         0.543810
# 11    VCI        2013       399458747857        -0.138641
# 12    VCI        2011       463753810568         0.000000
#
#     Attribute to parent company (Bn. VND)  \
# 0                            910692113293
# 1                            491904659394
# ...

# %%
df_4.shape
# Out:
# (13, 24)

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 24 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   CP                                                13 non-null     object
#  1   Năm                                               13 non-null     int64
#  2   Doanh thu (đồng)                                  13 non-null     int64
#  3   Tăng trưởng doanh thu (%)                         13 non-null     float64
#  4   Lợi nhuận sau thuế của Cổ đông công ty mẹ (đồng)  13 non-null     int64
#  5   Tăng trưởng lợi nhuận (%)                         13 non-null     float64
#  6   Doanh thu thuần                                   13 non-null     int64
#  7   Giá vốn hàng bán                                  13 non-null     int64
#  8   Lãi gộp                                           13 non-null     int64
# ...

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   ticker                                 13 non-null     object
#  1   yearReport                             13 non-null     int64
#  2   Revenue (Bn. VND)                      13 non-null     int64
#  3   Revenue YoY (%)                        13 non-null     float64
#  4   Attribute to parent company (Bn. VND)  13 non-null     int64
#  5   Attribute to parent company YoY (%)    13 non-null     float64
#  6   Net Sales                              13 non-null     int64
#  7   Cost of Sales                          13 non-null     int64
#  8   Gross Profit                           13 non-null     int64
#  9   Financial Income                       13 non-null     float64
# ...

# %%
df_5 = finance.balance_sheet(period='year',lang= 'vi')
df_5
# Out:
#      CP   Năm  TÀI SẢN NGẮN HẠN (đồng)  Tiền và tương đương tiền (đồng)  \
# 0   VCI  2024           26491835561026                    4743771932745
# 1   VCI  2023           17174448616966                     787897819240
# 2   VCI  2022           14157693071824                    3423501614803
# 3   VCI  2021           16568965942558                    1131748599533
# 4   VCI  2020            8312170798945                     642512983590
# 5   VCI  2019            7173102515011                     794511762602
# 6   VCI  2018            6430493843962                    1144361568890
# 7   VCI  2017            6342806740944                     486703202803
# 8   VCI  2016            3075625891871                     545670784533
# 9   VCI  2015            2423478575254                     158181741192
# 10  VCI  2014            2707101348631                     618777857754
# 11  VCI  2013            2090711345801                     312645301464
# ...

# %%
df_6 =  finance.balance_sheet(period='year',lang= 'en')
df_6
# Out:
#    ticker  yearReport  CURRENT ASSETS (Bn. VND)  \
# 0     VCI        2024            26491835561026
# 1     VCI        2023            17174448616966
# 2     VCI        2022            14157693071824
# 3     VCI        2021            16568965942558
# 4     VCI        2020             8312170798945
# 5     VCI        2019             7173102515011
# 6     VCI        2018             6430493843962
# 7     VCI        2017             6342806740944
# 8     VCI        2016             3075625891871
# 9     VCI        2015             2423478575254
# 10    VCI        2014             2707101348631
# 11    VCI        2013             2090711345801
# 12    VCI        2011             1795452129469
#
#     Cash and cash equivalents (Bn. VND)  Short-term investments (Bn. VND)  \
# 0                         4743771932745                    21072524575199
# 1                          787897819240                    15097165308797
# ...

# %%
df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   CP                                        13 non-null     object
#  1   Năm                                       13 non-null     int64
#  2   TÀI SẢN NGẮN HẠN (đồng)                   13 non-null     int64
#  3   Tiền và tương đương tiền (đồng)           13 non-null     int64
#  4   Giá trị thuần đầu tư ngắn hạn (đồng)      13 non-null     int64
#  5   Các khoản phải thu ngắn hạn (đồng)        13 non-null     int64
#  6   Hàng tồn kho ròng                         13 non-null     int64
#  7   Tài sản lưu động khác                     13 non-null     int64
#  8   TÀI SẢN DÀI HẠN (đồng)                    13 non-null     int64
#  9   Tài sản cố định (đồng)                    13 non-null     int64
# ...

# %%
df_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 32 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ticker                               13 non-null     object
#  1   yearReport                           13 non-null     int64
#  2   CURRENT ASSETS (Bn. VND)             13 non-null     int64
#  3   Cash and cash equivalents (Bn. VND)  13 non-null     int64
#  4   Short-term investments (Bn. VND)     13 non-null     int64
#  5   Accounts receivable (Bn. VND)        13 non-null     int64
#  6   Net Inventories                      13 non-null     int64
#  7   Other current assets                 13 non-null     int64
#  8   LONG-TERM ASSETS (Bn. VND)           13 non-null     int64
#  9   Fixed assets (Bn. VND)               13 non-null     int64
#  10  Long-term investments (Bn. VND)      13 non-null     int64
# ...

# %%
df_7 = finance.cash_flow(period = 'year',lang='vi')
df_7
# Out:
#      CP   Năm  Lãi/Lỗ ròng trước thuế  Khấu hao TSCĐ  Dự phòng RR tín dụng  \
# 0   VCI  2024           1089337104906    10751194638            4516800000
# 1   VCI  2023            570138640134     9679599271           11292000000
# 2   VCI  2022           1059738713385     9647191174                     0
# 3   VCI  2021           1850585393088     7496942452            -214202387
# 4   VCI  2020            951038957081    10634646105             -35400000
# 5   VCI  2019            855007109256    11729076470              22200000
# 6   VCI  2018           1011455908924    11577959706          -19945610083
# 7   VCI  2017            802977679615     9773790332          -15149537030
# 8   VCI  2016            415888536017     8060391011           22916148519
# 9   VCI  2015            300960284712     9770470117          -12721010619
# 10  VCI  2014            182828859179     6970993921          -45635182260
# ...

# %%
df_8 =finance.cash_flow(period = 'year',lang='en')
df_8
# Out:
#    ticker  yearReport  Net Profit/Loss before tax  \
# 0     VCI        2024               1089337104906
# 1     VCI        2023                570138640134
# 2     VCI        2022               1059738713385
# 3     VCI        2021               1850585393088
# 4     VCI        2020                951038957081
# 5     VCI        2019                855007109256
# 6     VCI        2018               1011455908924
# 7     VCI        2017                802977679615
# 8     VCI        2016                415888536017
# 9     VCI        2015                300960284712
# 10    VCI        2014                182828859179
# 11    VCI        2013                 90203867489
# 12    VCI        2011                 32501527420
#
#     Depreciation and Amortisation  Provision for credit losses  \
# 0                     10751194638                   4516800000
# 1                      9679599271                  11292000000
# 2                      9647191174                            0
# ...

# %%
df_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 38 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   CP                                                                   13 non-null     object
#  1   Năm                                                                  13 non-null     int64
#  2   Lãi/Lỗ ròng trước thuế                                               13 non-null     int64
#  3   Khấu hao TSCĐ                                                        13 non-null     int64
#  4   Dự phòng RR tín dụng                                                 13 non-null     int64
#  5   Lãi/Lỗ chênh lệch tỷ giá chưa thực hiện                              13 non-null     int64
#  6   Lãi/Lỗ từ hoạt động đầu tư                                           13 non-null     int64
# ...

# %%
df_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 38 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   ticker                                                                   13 non-null     object
#  1   yearReport                                                               13 non-null     int64
#  2   Net Profit/Loss before tax                                               13 non-null     int64
#  3   Depreciation and Amortisation                                            13 non-null     int64
#  4   Provision for credit losses                                              13 non-null     int64
#  5   Unrealized foreign exchange gain/loss                                    13 non-null     int64
# ...

# %%
df_9 = finance.ratio(period='year', lang='vi')
df_10 = finance.ratio(period='year', lang='en')

# %%
df_10
# Out:
#      Meta                         Chỉ tiêu cơ cấu nguồn vốn              \
#    ticker yearReport lengthReport (ST+LT borrowings)/Equity Debt/Equity
# 0     VCI       2024            5                  0.971382    1.054349
# 1     VCI       2023            5                  1.218152    1.340876
# 2     VCI       2022            5                  0.973942    1.192721
# 3     VCI       2021            5                  0.972610    1.543047
# 4     VCI       2020            5                  0.596293    0.853905
# 5     VCI       2019            5                  0.358125    0.787676
# 6     VCI       2018            5                  0.270345    0.786999
# 7     VCI       2017            5                  0.475082    1.120296
# 8     VCI       2016            5                  0.491563    1.436668
# 9     VCI       2015            5                  0.550475    1.532230
# 10    VCI       2014            5                  0.364664    2.686542
# ...

# %%
df_9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 37 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   (Meta, CP)                                                   13 non-null     object
#  1   (Meta, Năm)                                                  13 non-null     int64
#  2   (Meta, Kỳ)                                                   13 non-null     int64
#  3   (Chỉ tiêu cơ cấu nguồn vốn, (Vay NH+DH)/VCSH)                13 non-null     float64
#  4   (Chỉ tiêu cơ cấu nguồn vốn, Nợ/VCSH)                         13 non-null     float64
#  5   (Chỉ tiêu cơ cấu nguồn vốn, TSCĐ / Vốn CSH)                  13 non-null     float64
#  6   (Chỉ tiêu cơ cấu nguồn vốn, Vốn CSH/Vốn điều lệ)             13 non-null     float64
# ...

# %%
df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 37 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   (Meta, ticker)                                               13 non-null     object
#  1   (Meta, yearReport)                                           13 non-null     int64
#  2   (Meta, lengthReport)                                         13 non-null     int64
#  3   (Chỉ tiêu cơ cấu nguồn vốn, (ST+LT borrowings)/Equity)       13 non-null     float64
#  4   (Chỉ tiêu cơ cấu nguồn vốn, Debt/Equity)                     13 non-null     float64
#  5   (Chỉ tiêu cơ cấu nguồn vốn, Fixed Asset-To-Equity)           13 non-null     float64
#  6   (Chỉ tiêu cơ cấu nguồn vốn, Owners' Equity/Charter Capital)  13 non-null     float64
# ...

# %%
listing.all_indices()
# Out:
#          symbol         name  \
# 0          VN30         VN30
# 1         VNMID        VNMID
# 2         VNSML        VNSML
# 3         VN100        VN100
# 4         VNALL        VNALL
# 5          VNSI         VNSI
# 6          VNIT         VNIT
# 7         VNIND        VNIND
# 8        VNCONS       VNCONS
# 9        VNCOND       VNCOND
# 10       VNHEAL       VNHEAL
# 11        VNENE        VNENE
# 12        VNUTI        VNUTI
# 13       VNREAL       VNREAL
# 14        VNFIN        VNFIN
# 15        VNMAT        VNMAT
# 16    VNDIAMOND    VNDIAMOND
# 17    VNFINLEAD    VNFINLEAD
# 18  VNFINSELECT  VNFINSELECT
# 19        VNX50        VNX50
# 20       VNXALL       VNXALL
#
#                                           description  \
# 0   30 cổ phiếu vốn hóa lớn nhất & thanh khoản tốt...
# 1    Mid-Cap Index - nhóm cổ phiếu vốn hóa trung bình
# 2         Small-Cap Index - nhóm cổ phiếu vốn hóa nhỏ
# 3               100 cổ phiếu có vốn hoá lớn nhất HOSE
# ...

# %%
# !pip install openpyxl

# %%
import pandas as pd 
import openpyxl

# %%
df_hoanthanh = pd.read_csv(r"C:\Users\LENOVO\Downloads\Đã hoàn thành đơn hàng-2026-01-20-15_11.csv")
df_huydon = pd.read_csv(r"C:\Users\LENOVO\Downloads\Đã hủy đơn hàng-2026-01-20-19_38.csv")
df_kohoanthanh = pd.read_csv(r"C:\Users\LENOVO\Downloads\undefined đơn hàng-2026-01-20-19_39.csv")

# %%
with pd.ExcelWriter(r'D:\PYTHON\data_dep_boc.xlsx', engine= 'openpyxl') as writer:
    df_hoanthanh.to_excel(writer, sheet_name='HoanhThanh', index=False)
    df_huydon.to_excel(writer, sheet_name='HuyDon', index=False)
    df_kohoanthanh.to_excel(writer, sheet_name='GiaoKhongThangCong', index=False)
